# %%
import pandas as pd
import scrape_sequim_covid as sc
import seaborn as sns
sequim = sc.SequimCovid()
sequim.update_csv()
# Out:
# Data up to date

# %%
pd.options.display.max_columns = None
display(sequim.df.iloc[:,::-1])
# Out:
#                                               12/18/2020 12/17/2020  \
# New Cases                                              3          8
# Total Confirmed Cases                                658        655
# Total Hospitalizations                                26         26
# Currently Hospitalized                                 0          0
# Total Deaths                                           4          4
# Cases Recovered                                      603        596
# Total Tests Performed                             30,190     30,026
# Percent Positivity of Total Tests                   2.5%       2.4%
# Percent Positivity Last Two Weeks                   4.4%       4.4%
# Rate of Cases per 100,000 in the last 14 days        149        157
# Number of days rate <75/100,000                        0          0
# Number of days rate <26/100,000                        0          0
#
#                                               12/16/2020 12/15/2020  \
# ...

# %%
display(sequim.my_df.iloc[:,::-1])
# Out:
#                          12/18/2020  12/17/2020  12/16/2020  12/15/2020  \
# New Cases for Two Weeks         109         106         116         116
# Per 100,000                     141         137         150         150
#
#                          12/14/2020  12/13/2020  12/12/2020  12/11/2020  \
# New Cases for Two Weeks         128         135         131         157
# Per 100,000                     166         175         169         203
#
#                          12/10/2020  12/09/2020  12/08/2020  12/07/2020  \
# New Cases for Two Weeks         156         147         146         152
# Per 100,000                     202         190         189         197
#
#                          12/06/2020  12/05/2020  12/04/2020  12/03/2020  \
# New Cases for Two Weeks         158         165         145         168
# Per 100,000                     204         213         188         217
#
#                          12/02/2020  12/01/2020  11/30/2020  11/29/2020  \
# ...

# %%
sns.lineplot(data=sequim.df
            )

# %%
sns.lineplot(data=sequim.confirmed_twoweek)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=sequim.confirmed_twoweek)
