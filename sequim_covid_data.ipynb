# %%
import pandas as pd
import scrape_sequim_covid as sc
sequim = sc.SequimCovid()
sequim.update_csv()
# Out:
# Complete 1/2
# Complete 2/2
# Complete

# %%
pd.options.display.max_columns = None
display(sequim.df.iloc[:,::-1])
# Out:
#                                                   12/01/2020 11/30/2020  \
# New Cases                                                 17         11
# Total Confirmed Cases                                    516        499
# Total Hospitalizations                                    22         19
# Currently Hospitalized                                     6          3
# Total Deaths                                               4          2
# Cases Recovered                                          345        345
# Total Tests Performed                                 27,034     26,594
# Percent Positivity of Total Tests                       2.2%       2.2%
# Percent Positivity Last Two Weeks (11-8 to 11-22)       5.6%       5.5%
# Rate of Cases per 100,000 in the last 14 days            222        218
# Number of days rate <75/100,000                            0          0
# Number of days rate <26/100,000                            0          0
#
#                                                   11/29/2020 11/28/2020  \
# New Cases                                                  1         31
# Total Confirmed Cases                                    488        487
# Total Hospitalizations                                    17         17
# Currently Hospitalized                                     3          3
# Total Deaths                                               2          2
# Cases Recovered                                          335        335
# Total Tests Performed                                 25,763     25,763
# Percent Positivity of Total Tests                       2.0%       2.0%
# Percent Positivity Last Two Weeks (11-8 to 11-22)       5.3%       5.3%
# Rate of Cases per 100,000 in the last 14 days            188        188
# Number of days rate <75/100,000                            0          0
# Number of days rate <26/100,000                            0          0
#
#                                                    11/27/2020  11/26/2020  \
# New Cases                                                 0.0         0.0
# Total Confirmed Cases                                   456.0         NaN
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                           NaN         NaN
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    11/25/2020  11/24/2020  \
# New Cases                                                 6.0        10.0
# Total Confirmed Cases                                   456.0       450.0
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                           NaN         NaN
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    11/23/2020  11/22/2020  \
# New Cases                                                17.0        10.0
# Total Confirmed Cases                                   440.0       423.0
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                           NaN         NaN
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    11/21/2020  11/20/2020  \
# New Cases                                                 7.0        23.0
# Total Confirmed Cases                                   413.0       406.0
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                           NaN         NaN
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    11/19/2020  11/18/2020  \
# New Cases                                                18.0        13.0
# Total Confirmed Cases                                   383.0       365.0
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                           NaN         NaN
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    11/17/2020  11/16/2020  \
# New Cases                                                 4.0        16.0
# Total Confirmed Cases                                   352.0       348.0
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                           NaN         NaN
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    11/15/2020  11/14/2020  \
# New Cases                                                 6.0         8.0
# Total Confirmed Cases                                   332.0       326.0
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                          77.0        76.0
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    11/13/2020  11/12/2020  \
# New Cases                                                 4.0         5.0
# Total Confirmed Cases                                   318.0       314.0
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                          75.0        74.0
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    11/11/2020  11/10/2020  \
# New Cases                                                 5.0         1.0
# Total Confirmed Cases                                   309.0       304.0
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                          73.0        72.0
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    11/9/2020  11/8/2020  \
# New Cases                                                4.0        NaN
# Total Confirmed Cases                                  303.0        NaN
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                         71.0       70.0
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    11/7/2020  11/6/2020  \
# New Cases                                                5.0        3.0
# Total Confirmed Cases                                  299.0      294.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                         69.0       68.0
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    11/5/2020  11/4/2020  \
# New Cases                                                3.0        2.0
# Total Confirmed Cases                                  291.0      288.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                         67.0       66.0
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    11/3/2020  11/2/2020  \
# New Cases                                                NaN        NaN
# Total Confirmed Cases                                    NaN        NaN
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                         65.0       64.0
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    11/1/2020  10/31/2020  \
# New Cases                                                NaN         2.0
# Total Confirmed Cases                                    NaN       286.0
# Total Hospitalizations                                   NaN         NaN
# Currently Hospitalized                                   NaN         NaN
# Total Deaths                                             NaN         NaN
# Cases Recovered                                          NaN         NaN
# Total Tests Performed                                    NaN         NaN
# Percent Positivity of Total Tests                        NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN         NaN
# Rate of Cases per 100,000 in the last 14 days            NaN         NaN
# Number of days rate <75/100,000                         63.0        62.0
# Number of days rate <26/100,000                          NaN         NaN
#
#                                                    10/30/2020  10/29/2020  \
# New Cases                                                 NaN         NaN
# Total Confirmed Cases                                     NaN         NaN
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                          61.0        60.0
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    10/28/2020  10/27/2020  \
# New Cases                                                 5.0         NaN
# Total Confirmed Cases                                   284.0         NaN
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                          59.0        58.0
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    10/26/2020  10/25/2020  \
# New Cases                                                 NaN         2.0
# Total Confirmed Cases                                     NaN       279.0
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                          57.0        56.0
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    10/24/2020  10/23/2020  \
# New Cases                                                 3.0         2.0
# Total Confirmed Cases                                   277.0       274.0
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                          55.0        54.0
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    10/22/2020  10/21/2020  \
# New Cases                                                 1.0         4.0
# Total Confirmed Cases                                   272.0       271.0
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                          53.0        52.0
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    10/20/2020  10/19/2020  \
# New Cases                                                 NaN         2.0
# Total Confirmed Cases                                     NaN       267.0
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                          51.0        50.0
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    10/18/2020  10/17/2020  \
# New Cases                                                 NaN         1.0
# Total Confirmed Cases                                     NaN       265.0
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                          49.0        48.0
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    10/16/2020  10/15/2020  \
# New Cases                                                 3.0         1.0
# Total Confirmed Cases                                   264.0       261.0
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                          47.0        46.0
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    10/14/2020  10/13/2020  \
# New Cases                                                 1.0         NaN
# Total Confirmed Cases                                   260.0         NaN
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                          45.0        44.0
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    10/12/2020  10/11/2020  \
# New Cases                                                 NaN         2.0
# Total Confirmed Cases                                     NaN       259.0
# Total Hospitalizations                                    NaN         NaN
# Currently Hospitalized                                    NaN         NaN
# Total Deaths                                              NaN         NaN
# Cases Recovered                                           NaN         NaN
# Total Tests Performed                                     NaN         NaN
# Percent Positivity of Total Tests                         NaN         NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN         NaN
# Rate of Cases per 100,000 in the last 14 days             NaN         NaN
# Number of days rate <75/100,000                          43.0        42.0
# Number of days rate <26/100,000                           NaN         NaN
#
#                                                    10/10/2020  10/9/2020  \
# New Cases                                                 2.0        1.0
# Total Confirmed Cases                                   257.0      255.0
# Total Hospitalizations                                    NaN        NaN
# Currently Hospitalized                                    NaN        NaN
# Total Deaths                                              NaN        NaN
# Cases Recovered                                           NaN        NaN
# Total Tests Performed                                     NaN        NaN
# Percent Positivity of Total Tests                         NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)         NaN        NaN
# Rate of Cases per 100,000 in the last 14 days             NaN        NaN
# Number of days rate <75/100,000                          41.0       40.0
# Number of days rate <26/100,000                           NaN        NaN
#
#                                                    10/8/2020  10/7/2020  \
# New Cases                                                1.0        2.0
# Total Confirmed Cases                                  254.0      253.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                         39.0       38.0
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    10/6/2020  10/5/2020  \
# New Cases                                                1.0        1.0
# Total Confirmed Cases                                  251.0      250.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                         37.0       36.0
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    10/4/2020  10/3/2020  \
# New Cases                                                1.0        1.0
# Total Confirmed Cases                                  249.0      248.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                         35.0       34.0
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    10/2/2020  10/1/2020  \
# New Cases                                                1.0        1.0
# Total Confirmed Cases                                  247.0      246.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                         33.0       32.0
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    9/30/2020  9/29/2020  \
# New Cases                                                2.0        NaN
# Total Confirmed Cases                                  245.0        NaN
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    9/28/2020  9/27/2020  \
# New Cases                                                1.0        NaN
# Total Confirmed Cases                                  243.0        NaN
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    9/26/2020  9/25/2020  \
# New Cases                                                1.0        NaN
# Total Confirmed Cases                                  242.0        NaN
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    9/24/2020  9/23/2020  \
# New Cases                                                4.0        1.0
# Total Confirmed Cases                                  241.0      237.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    9/22/2020  9/21/2020  \
# New Cases                                                NaN        1.0
# Total Confirmed Cases                                    NaN      236.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    9/20/2020  9/19/2020  \
# New Cases                                                2.0        1.0
# Total Confirmed Cases                                  235.0      233.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    9/18/2020  9/17/2020  \
# New Cases                                                2.0        1.0
# Total Confirmed Cases                                  232.0      230.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    9/16/2020  9/15/2020  \
# New Cases                                                2.0        1.0
# Total Confirmed Cases                                  229.0      227.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    9/14/2020  9/13/2020  \
# New Cases                                                NaN        NaN
# Total Confirmed Cases                                    NaN        NaN
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    9/12/2020  9/11/2020  \
# New Cases                                                NaN        5.0
# Total Confirmed Cases                                    NaN      226.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    9/10/2020  9/9/2020  \
# New Cases                                                NaN       NaN
# Total Confirmed Cases                                    NaN       NaN
# Total Hospitalizations                                   NaN       NaN
# Currently Hospitalized                                   NaN       NaN
# Total Deaths                                             NaN       NaN
# Cases Recovered                                          NaN       NaN
# Total Tests Performed                                    NaN       NaN
# Percent Positivity of Total Tests                        NaN       NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN       NaN
# Rate of Cases per 100,000 in the last 14 days            NaN       NaN
# Number of days rate <75/100,000                          NaN       NaN
# Number of days rate <26/100,000                          NaN       NaN
#
#                                                    9/8/2020  9/7/2020  \
# New Cases                                               NaN       NaN
# Total Confirmed Cases                                   NaN       NaN
# Total Hospitalizations                                  NaN       NaN
# Currently Hospitalized                                  NaN       NaN
# Total Deaths                                            NaN       NaN
# Cases Recovered                                         NaN       NaN
# Total Tests Performed                                   NaN       NaN
# Percent Positivity of Total Tests                       NaN       NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)       NaN       NaN
# Rate of Cases per 100,000 in the last 14 days           NaN       NaN
# Number of days rate <75/100,000                         NaN       NaN
# Number of days rate <26/100,000                         NaN       NaN
#
#                                                    9/6/2020  9/5/2020  \
# New Cases                                               NaN       NaN
# Total Confirmed Cases                                   NaN       NaN
# Total Hospitalizations                                  NaN       NaN
# Currently Hospitalized                                  NaN       NaN
# Total Deaths                                            NaN       NaN
# Cases Recovered                                         NaN       NaN
# Total Tests Performed                                   NaN       NaN
# Percent Positivity of Total Tests                       NaN       NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)       NaN       NaN
# Rate of Cases per 100,000 in the last 14 days           NaN       NaN
# Number of days rate <75/100,000                         NaN       NaN
# Number of days rate <26/100,000                         NaN       NaN
#
#                                                    9/4/2020  9/3/2020  \
# New Cases                                               4.0       4.0
# Total Confirmed Cases                                 221.0     217.0
# Total Hospitalizations                                  NaN       NaN
# Currently Hospitalized                                  NaN       NaN
# Total Deaths                                            NaN       NaN
# Cases Recovered                                         NaN       NaN
# Total Tests Performed                                   NaN       NaN
# Percent Positivity of Total Tests                       NaN       NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)       NaN       NaN
# Rate of Cases per 100,000 in the last 14 days           NaN       NaN
# Number of days rate <75/100,000                         NaN       NaN
# Number of days rate <26/100,000                         NaN       NaN
#
#                                                    9/2/2020  9/1/2020  \
# New Cases                                               1.0       NaN
# Total Confirmed Cases                                 213.0       NaN
# Total Hospitalizations                                  NaN       NaN
# Currently Hospitalized                                  NaN       NaN
# Total Deaths                                            NaN       NaN
# Cases Recovered                                         NaN       NaN
# Total Tests Performed                                   NaN       NaN
# Percent Positivity of Total Tests                       NaN       NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)       NaN       NaN
# Rate of Cases per 100,000 in the last 14 days           NaN       NaN
# Number of days rate <75/100,000                         NaN       NaN
# Number of days rate <26/100,000                         NaN       NaN
#
#                                                    8/31/2020  8/30/2020  \
# New Cases                                                NaN        2.0
# Total Confirmed Cases                                    NaN      212.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    8/29/2020  8/28/2020  \
# New Cases                                                3.0        1.0
# Total Confirmed Cases                                  210.0      207.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    8/27/2020  8/26/2020  \
# New Cases                                                3.0        4.0
# Total Confirmed Cases                                  206.0      203.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# ...
# Currently Hospitalized                                  NaN       NaN
# Total Deaths                                            NaN       NaN
# Cases Recovered                                         NaN       NaN
# Total Tests Performed                                   NaN       NaN
# Percent Positivity of Total Tests                       NaN       NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)       NaN       NaN
# Rate of Cases per 100,000 in the last 14 days           NaN       NaN
# Number of days rate <75/100,000                         NaN       NaN
# Number of days rate <26/100,000                         NaN       NaN
#
#                                                    8/1/2020  7/31/2020  \
# New Cases                                               2.0        2.0
# Total Confirmed Cases                                   NaN       96.0
# Total Hospitalizations                                  NaN        NaN
# Currently Hospitalized                                  NaN        NaN
# Total Deaths                                            NaN        NaN
# Cases Recovered                                         NaN        NaN
# Total Tests Performed                                   NaN        NaN
# Percent Positivity of Total Tests                       NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)       NaN        NaN
# Rate of Cases per 100,000 in the last 14 days           NaN        NaN
# Number of days rate <75/100,000                         NaN        NaN
# Number of days rate <26/100,000                         NaN        NaN
#
#                                                    7/30/2020  7/29/2020  \
# New Cases                                                2.0        3.0
# Total Confirmed Cases                                   94.0       92.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    7/28/2020  7/27/2020  \
# New Cases                                                7.0        1.0
# Total Confirmed Cases                                   89.0       82.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    7/26/2020  7/25/2020  \
# New Cases                                                3.0        2.0
# Total Confirmed Cases                                   81.0       78.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    7/24/2020  7/23/2020  \
# New Cases                                                2.0        2.0
# Total Confirmed Cases                                   76.0       74.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    7/21/2020  7/20/2020  \
# New Cases                                                4.0        NaN
# Total Confirmed Cases                                   72.0        NaN
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    7/19/2020  7/18/2020  \
# New Cases                                                NaN        NaN
# Total Confirmed Cases                                    NaN        NaN
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    7/17/2020  7/16/2020  \
# New Cases                                                NaN        NaN
# Total Confirmed Cases                                    NaN        NaN
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    7/15/2020  7/14/2020  \
# New Cases                                                NaN        NaN
# Total Confirmed Cases                                    NaN        NaN
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    7/13/2020  7/12/2020  \
# New Cases                                                NaN        NaN
# Total Confirmed Cases                                    NaN        NaN
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    7/11/2020  7/10/2020  \
# New Cases                                                5.0        4.0
# Total Confirmed Cases                                   59.0       54.0
# Total Hospitalizations                                   NaN        NaN
# Currently Hospitalized                                   NaN        NaN
# Total Deaths                                             NaN        NaN
# Cases Recovered                                          NaN        NaN
# Total Tests Performed                                    NaN        NaN
# Percent Positivity of Total Tests                        NaN        NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)        NaN        NaN
# Rate of Cases per 100,000 in the last 14 days            NaN        NaN
# Number of days rate <75/100,000                          NaN        NaN
# Number of days rate <26/100,000                          NaN        NaN
#
#                                                    7/9/2020  7/8/2020  \
# New Cases                                               3.0       NaN
# Total Confirmed Cases                                  50.0       NaN
# Total Hospitalizations                                  NaN       NaN
# Currently Hospitalized                                  NaN       NaN
# Total Deaths                                            NaN       NaN
# Cases Recovered                                         NaN       NaN
# Total Tests Performed                                   NaN       NaN
# Percent Positivity of Total Tests                       NaN       NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)       NaN       NaN
# Rate of Cases per 100,000 in the last 14 days           NaN       NaN
# Number of days rate <75/100,000                         NaN       NaN
# Number of days rate <26/100,000                         NaN       NaN
#
#                                                    7/7/2020  7/6/2020  \
# New Cases                                               NaN       NaN
# Total Confirmed Cases                                  46.0       NaN
# Total Hospitalizations                                  NaN       NaN
# Currently Hospitalized                                  NaN       NaN
# Total Deaths                                            NaN       NaN
# Cases Recovered                                         NaN       NaN
# Total Tests Performed                                   NaN       NaN
# Percent Positivity of Total Tests                       NaN       NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)       NaN       NaN
# Rate of Cases per 100,000 in the last 14 days           NaN       NaN
# Number of days rate <75/100,000                         NaN       NaN
# Number of days rate <26/100,000                         NaN       NaN
#
#                                                    7/5/2020  7/4/2020  \
# New Cases                                               NaN       1.0
# Total Confirmed Cases                                   NaN      45.0
# Total Hospitalizations                                  NaN       NaN
# Currently Hospitalized                                  NaN       NaN
# Total Deaths                                            NaN       NaN
# Cases Recovered                                         NaN       NaN
# Total Tests Performed                                   NaN       NaN
# Percent Positivity of Total Tests                       NaN       NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)       NaN       NaN
# Rate of Cases per 100,000 in the last 14 days           NaN       NaN
# Number of days rate <75/100,000                         NaN       NaN
# Number of days rate <26/100,000                         NaN       NaN
#
#                                                    7/3/2020  7/2/2020  \
# New Cases                                               NaN       NaN
# Total Confirmed Cases                                   NaN       NaN
# Total Hospitalizations                                  NaN       NaN
# Currently Hospitalized                                  NaN       NaN
# Total Deaths                                            NaN       NaN
# Cases Recovered                                         NaN       NaN
# Total Tests Performed                                   NaN       NaN
# Percent Positivity of Total Tests                       NaN       NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)       NaN       NaN
# Rate of Cases per 100,000 in the last 14 days           NaN       NaN
# Number of days rate <75/100,000                         NaN       NaN
# Number of days rate <26/100,000                         NaN       NaN
#
#                                                    7/1/2020
# New Cases                                               NaN
# Total Confirmed Cases                                   2.0
# Total Hospitalizations                                  NaN
# Currently Hospitalized                                  NaN
# Total Deaths                                            NaN
# Cases Recovered                                         NaN
# Total Tests Performed                                   NaN
# Percent Positivity of Total Tests                       NaN
# Percent Positivity Last Two Weeks (11-8 to 11-22)       NaN
# Rate of Cases per 100,000 in the last 14 days           NaN
# Number of days rate <75/100,000                         NaN
# Number of days rate <26/100,000                         NaN

# %%
display(sequim.my_df.iloc[:,::-1])
# Out:
#                          12/01/2020  11/30/2020  11/29/2020  11/28/2020  \
# New Cases for Two Weeks         164         151         156         161
# Per 100,000                     212         195         202         208
#
#                          11/27/2020  11/26/2020  11/25/2020  11/24/2020  \
# New Cases for Two Weeks         138         142         147         146
# Per 100,000                     178         184         190         188
#
#                          11/23/2020  11/22/2020  11/21/2020  11/20/2020  \
# New Cases for Two Weeks         137         124         114         112
# Per 100,000                     177         160         147         144
#
#                          11/19/2020  11/18/2020  11/17/2020  11/16/2020  \
# New Cases for Two Weeks          92          77          66          62
# Per 100,000                     119          99          85          80
#
#                          11/15/2020  11/14/2020  11/13/2020  11/12/2020  \
# New Cases for Two Weeks          46          40          34          30
# Per 100,000                      59          52          44          39
#
#                          11/11/2020  11/10/2020  11/9/2020  11/8/2020  \
# New Cases for Two Weeks          25          25         24         20
# Per 100,000                      32          32         30         26
#
#                          11/7/2020  11/6/2020  11/5/2020  11/4/2020  \
# New Cases for Two Weeks         22         20         20         18
# Per 100,000                     28         26         26         23
#
#                          11/3/2020  11/2/2020  11/1/2020  10/31/2020  \
# New Cases for Two Weeks         20         20         22          22
# Per 100,000                     26         26         28          28
#
#                          10/30/2020  10/29/2020  10/28/2020  10/27/2020  \
# New Cases for Two Weeks          21          24          26          21
# Per 100,000                      27          31          34          27
#
#                          10/26/2020  10/25/2020  10/24/2020  10/23/2020  \
# New Cases for Two Weeks          21          21          21          19
# Per 100,000                      27          27          27          25
#
#                          10/22/2020  10/21/2020  10/20/2020  10/19/2020  \
# New Cases for Two Weeks          16          16          14          15
# Per 100,000                      21          21          18          19
#
#                          10/18/2020  10/17/2020  10/16/2020  10/15/2020  \
# New Cases for Two Weeks          14          15          15          13
# Per 100,000                      18          19          19          17
#
#                          10/14/2020  10/13/2020  10/12/2020  10/11/2020  \
# New Cases for Two Weeks          13          14          14          15
# Per 100,000                      17          18          18          19
#
#                          10/10/2020  10/9/2020  10/8/2020  10/7/2020  \
# New Cases for Two Weeks          13         14         13         16
# Per 100,000                      17         18         17         21
#
#                          10/6/2020  10/5/2020  10/4/2020  10/3/2020  \
# New Cases for Two Weeks         15         14         14         15
# Per 100,000                     19         18         18         19
#
#                          10/2/2020  10/1/2020  9/30/2020  9/29/2020  \
# New Cases for Two Weeks         15         16        NaN        NaN
# Per 100,000                     19         21       16.0       16.0
#
#                          9/28/2020  9/27/2020  9/26/2020  9/25/2020  \
# New Cases for Two Weeks        NaN        NaN        NaN        NaN
# Per 100,000                   17.0       16.0       16.0       15.0
#
#                          9/24/2020  9/23/2020  9/22/2020  9/21/2020  \
# New Cases for Two Weeks        NaN        NaN        NaN        NaN
# Per 100,000                   20.0       16.0       15.0       15.0
#
#                          9/20/2020  9/19/2020  9/18/2020  9/17/2020  \
# New Cases for Two Weeks        NaN        NaN        NaN        NaN
# Per 100,000                   13.0       12.0       14.0       17.0
#
#                          9/16/2020  9/15/2020  9/14/2020  9/13/2020  \
# New Cases for Two Weeks        NaN        NaN        NaN        NaN
# Per 100,000                   21.0       19.0       18.0       18.0
#
#                          9/12/2020  9/11/2020  9/10/2020  9/9/2020  9/8/2020  \
# New Cases for Two Weeks        NaN        NaN        NaN       NaN       NaN
# Per 100,000                   21.0       25.0       19.0      23.0      39.0
#
#                          9/7/2020  9/6/2020  9/5/2020  9/4/2020  9/3/2020  \
# New Cases for Two Weeks       NaN       NaN       NaN       NaN       NaN
# Per 100,000                  39.0      45.0      46.0      52.0      58.0
#
#                          9/2/2020  9/1/2020
# New Cases for Two Weeks       NaN       NaN
# Per 100,000                  56.0      55.0

# %%
display(sequim.my_df.iloc[:,::-1])
# Out:
#                          11/30/2020  11/29/2020  11/28/2020  11/27/2020  \
# New Cases for Two Weeks         151         156         161         138
# Per 100,000                     195         202         208         178
#
#                          11/26/2020  11/25/2020  11/24/2020  11/23/2020  \
# New Cases for Two Weeks         142         147         146         137
# Per 100,000                     184         190         188         177
#
#                          11/22/2020  11/21/2020  11/20/2020  11/19/2020  \
# New Cases for Two Weeks         124         114         112          92
# Per 100,000                     160         147         144         119
#
#                          11/18/2020  11/17/2020  11/16/2020  11/15/2020  \
# New Cases for Two Weeks          77          66          62          46
# Per 100,000                      99          85          80          59
#
#                          11/14/2020  11/13/2020  11/12/2020  11/11/2020  \
# New Cases for Two Weeks          40          34          30          25
# Per 100,000                      52          44          39          32
#
#                          11/10/2020  11/9/2020  11/8/2020  11/7/2020  \
# New Cases for Two Weeks          25         24         20         22
# Per 100,000                      32         30         26         28
#
#                          11/6/2020  11/5/2020  11/4/2020  11/3/2020  \
# New Cases for Two Weeks         20         20         18         20
# Per 100,000                     26         26         23         26
#
#                          11/2/2020  11/1/2020  10/31/2020  10/30/2020  \
# New Cases for Two Weeks         20         22          22          21
# Per 100,000                     26         28          28          27
#
#                          10/29/2020  10/28/2020  10/27/2020  10/26/2020  \
# New Cases for Two Weeks          24          26          21          21
# Per 100,000                      31          34          27          27
#
#                          10/25/2020  10/24/2020  10/23/2020  10/22/2020  \
# New Cases for Two Weeks          21          21          19          16
# Per 100,000                      27          27          25          21
#
#                          10/21/2020  10/20/2020  10/19/2020  10/18/2020  \
# New Cases for Two Weeks          16          14          15          14
# Per 100,000                      21          18          19          18
#
#                          10/17/2020  10/16/2020  10/15/2020  10/14/2020  \
# New Cases for Two Weeks          15          15          13          13
# Per 100,000                      19          19          17          17
#
#                          10/13/2020  10/12/2020  10/11/2020  10/10/2020  \
# New Cases for Two Weeks          14          14          15          13
# Per 100,000                      18          18          19          17
#
#                          10/9/2020  10/8/2020  10/7/2020  10/6/2020  \
# New Cases for Two Weeks         14         13         16         15
# Per 100,000                     18         17         21         19
#
#                          10/5/2020  10/4/2020  10/3/2020  10/2/2020  \
# New Cases for Two Weeks         14         14         15         15
# Per 100,000                     18         18         19         19
#
#                          10/1/2020  9/30/2020  9/29/2020  9/28/2020  \
# New Cases for Two Weeks         16        NaN        NaN        NaN
# Per 100,000                     21       16.0       16.0       17.0
#
#                          9/27/2020  9/26/2020  9/25/2020  9/24/2020  \
# New Cases for Two Weeks        NaN        NaN        NaN        NaN
# Per 100,000                   16.0       16.0       15.0       20.0
#
#                          9/23/2020  9/22/2020  9/21/2020  9/20/2020  \
# New Cases for Two Weeks        NaN        NaN        NaN        NaN
# Per 100,000                   16.0       15.0       15.0       13.0
#
#                          9/19/2020  9/18/2020  9/17/2020  9/16/2020  \
# New Cases for Two Weeks        NaN        NaN        NaN        NaN
# Per 100,000                   12.0       14.0       17.0       21.0
#
#                          9/15/2020  9/14/2020  9/13/2020  9/12/2020  \
# New Cases for Two Weeks        NaN        NaN        NaN        NaN
# Per 100,000                   19.0       18.0       18.0       21.0
#
#                          9/11/2020  9/10/2020  9/9/2020  9/8/2020  9/7/2020  \
# New Cases for Two Weeks        NaN        NaN       NaN       NaN       NaN
# Per 100,000                   25.0       19.0      23.0      39.0      39.0
#
#                          9/6/2020  9/5/2020  9/4/2020  9/3/2020  9/2/2020  \
# New Cases for Two Weeks       NaN       NaN       NaN       NaN       NaN
# Per 100,000                  45.0      46.0      52.0      58.0      56.0
#
#                          9/1/2020
# New Cases for Two Weeks       NaN
# Per 100,000                  55.0
