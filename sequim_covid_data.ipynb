# %%
import pandas as pd
import scrape_sequim_covid as sc
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
sequim = sc.SequimCovid()
sequim.update_csv()
sequim.convert_chart_data()
tw = sequim.get_twoweek_chart()
mn = sequim.get_month_chart()
# Out:
# Data up to date

# %%
pd.options.display.max_columns = None
display(sequim.df.iloc[:,::-1])
# Out:
#                                               12/19/2020 12/18/2020  \
# New Cases                                             11          3
# Total Confirmed Cases                                669        658
# Total Hospitalizations                                26         26
# Currently Hospitalized                                 0          0
# Total Deaths                                           4          4
# Cases Recovered                                      603        603
# Total Tests Performed                             30,190     30,190
# Percent Positivity of Total Tests                   2.5%       2.5%
# Percent Positivity Last Two Weeks                   4.4%       4.4%
# Rate of Cases per 100,000 in the last 14 days        149        149
# Number of days rate <75/100,000                        0          0
# Number of days rate <26/100,000                        0          0
#
#                                               12/17/2020 12/16/2020  \
# ...

# %%
display(sequim.my_df.iloc[:,::-1])
# Out:
#                          12/19/2020  12/18/2020  12/17/2020  12/16/2020  \
# New Cases for Two Weeks          93         109         106         116
# Per 100,000                     120         141         137         150
#
#                          12/15/2020  12/14/2020  12/13/2020  12/12/2020  \
# New Cases for Two Weeks         116         128         135         131
# Per 100,000                     150         166         175         169
#
#                          12/11/2020  12/10/2020  12/09/2020  12/08/2020  \
# New Cases for Two Weeks         157         156         147         146
# Per 100,000                     203         202         190         189
#
#                          12/07/2020  12/06/2020  12/05/2020  12/04/2020  \
# New Cases for Two Weeks         152         158         165         145
# Per 100,000                     197         204         213         188
#
#                          12/03/2020  12/02/2020  12/01/2020  11/30/2020  \
# ...

# %%
plt.figure(figsize=(10,5))
plt.title("Confirmed cases for last 30 days")
chart = sns.lineplot(data=mn['Total Confirmed Cases'])

plt.xticks(
    rotation=-45, 
    horizontalalignment='left',
    fontsize='small'  
);

# %%
plt.figure(figsize=(10,5))
plt.title('New cases for last 30 days')
chart = sns.lineplot(data=mn['New Cases'])

plt.xticks(
    rotation=-45, 
    horizontalalignment='left',
    fontsize='small'  
);
plt.ylim(ymin=0.0)

# %%
fig, ax =plt.subplots(1,2, figsize=(12,3))
sns.lineplot(data=tw['Total Confirmed Cases'], ax=ax[0])
sns.lineplot(data=tw['New Cases'], ax=ax[1])
fig.autofmt_xdate()

# %%
fig, ax =plt.subplots(1,2, figsize=(12,3))
sns.lineplot(data=tw['Total Confirmed Cases'], ax=ax[0])
sns.lineplot(data=tw['New Cases'], ax=ax[1])
fig.autofmt_xdate()
# Out:
# (0.0, 32.55)

# %%
fig, ax =plt.subplots(1,2, figsize=(12,3))
sns.lineplot(data=tw['Total Confirmed Cases'], ax=ax[0])
sns.lineplot(data=tw['New Cases'], ax=ax[1])
fig.autofmt_xdate()
